# %%
import pandas as pd
import numpy as np

# %%
us2012 = pd.read_csv("../data/background/us2012.csv")
# Out:
# /var/folders/hv/08dyyt957zq3n_n6kttfl_180000gn/T/ipykernel_19481/3675636070.py:1: DtypeWarning: Columns (8,9,10,21,22,23,75,104,106,107,108,117,118,240,251,252,253,254,255,256,257,258,259,260,261,262,263,264,265,266,267,268,269,270,271,281,282,283,284,285,286,287,288,289,290,291,292,294,296,299,308,309,315,316,317,324,393,395,396,397,398,409,410,411,414,421,422,426,427,437,441,445,449,453,457,461,465,469,473,477,485,497,501,505,509,513,517,521,529,533,537,541,545,557,561,565,569,573,577,581,585,597,605,609,613,617,641,645,653,657,661,665,669,673,677,681,685,689,693,697,701,705,709,713,717,721,725,729,733,737,741,745,749,753,757,761,765,769,773,777,781,785,789,793,797,801,805,809,813,821,829,833,837,841,845,849,896,898,899,900,901,903,904,907,908,909,917,918,919,920,921,922,923,924,925,926,927,937,938,939,940,941,942,943,944,945,946,947,948,949,950,951,952,953,954,955,956,958,960,962,964,966,968,970,972,974,976,978,980,982,984,986,988,990,992,994,996,998,1000,1002,1004,1006,1008,1010,
# ...

# %%
us2012
# Out:
#       CNTRYID  CNTRYID_E  SEQID AGE_R  GENDER_R  DISP_CIBQ DISP_MAIN  \
# 0         840        840      1     N         1          1         N
# 1         840        840      2     N         1          1         N
# 2         840        840      3     N         2          1         N
# 3         840        840      4     N         1          1         N
# 4         840        840      5     N         2          1         N
# ...       ...        ...    ...   ...       ...        ...       ...
# 5005      840        840   5006     N         2          1         N
# 5006      840        840   5007     N         2          1         N
# 5007      840        840   5008     N         2          1         N
# 5008      840        840   5009     N         1          1         N
# 5009      840        840   5010     N         2          1         N
#
#      DISP_MAINWRC A_N01_T B_Q01a  ...      READHOME READHOME_WLE_CA  \
# 0               N       1     11  ...  1.4142235073             2.0
# ...

# %%
us2012 = us2012.loc[:, ['SEQID', 'BIRTHRGN']]
#us2017 = us2017.loc[:, ['SEQID', 'BIRTHRGN']]

# %%
us2012
# Out:
#       SEQID BIRTHRGN
# 0         1        N
# 1         2        N
# 2         3        N
# 3         4        N
# 4         5        N
# ...     ...      ...
# 5005   5006        N
# 5006   5007        N
# 5007   5008        N
# 5008   5009        N
# 5009   5010        N
#
# [5010 rows x 2 columns]

# %%
print(us2012["FIRLGRGN"].unique())
# Out:
# ['N' nan]

# %%
rus = pd.read_csv("../data/background/prgrusp1.csv")
# Out:
# C:\Users\yukef\AppData\Local\Temp\ipykernel_17756\131533779.py:1: DtypeWarning: Columns (4,6,9,10,21,75,107,108,118,240,251,252,253,254,255,256,257,258,259,260,261,262,263,264,265,266,267,268,269,270,271,282,283,284,287,293,294,295,296,299,308,309,384,385,405,409,410,411,421,422,426,427,437,441,445,449,453,457,461,465,469,473,485,509,533,537,541,545,549,553,565,569,573,577,581,585,601,605,633,649,657,661,665,669,673,689,693,705,709,713,721,725,729,737,741,745,749,753,757,761,773,781,785,797,801,821,829,849,909,910,911,912,913,914,917,918,919,920,921,922,923,924,925,926,927,928,929,930,931,937,938,939,940,941,942,943,944,945,946,947,948,949,950) have mixed types. Specify dtype option on import or set low_memory=False.
#   rus = pd.read_csv("../data/background/prgrusp1.csv")

# %%
rus = rus.loc[:, ['SEQID', 'BIRTHRGN', 'CTRYRGN','FIRLGRGN']]  # russia
print(rus["BIRTHRGN"].unique())
# Out:
# ['8' 'N' '5' '6' '1' '9']

# %%
bel = pd.read_csv("../data/background/prgbelp1.csv")  # Belgium
bel = bel.loc[:, ['SEQID', 'BIRTHRGN', 'CTRYRGN','FIRLGRGN']]
print(bel["BIRTHRGN"].unique())
# Out:
# ['9' nan '8' '6' 'N' '2' '1' '5' '4' '3']
# ...

# %%
can = pd.read_csv("../data/background/prgcanp1.csv")  # Cananda
can = can.loc[:, ['SEQID', 'BIRTHRGN', 'CTRYRGN','FIRLGRGN']]
print(can["BIRTHRGN"].unique())
# Out:
# C:\Users\yukef\AppData\Local\Temp\ipykernel_17756\1478562711.py:1: DtypeWarning: Columns (10,21,22,23,74,103,105,107,116,117,239,250,251,252,253,254,255,256,257,258,259,260,261,262,263,264,265,266,267,268,269,270,280,281,282,283,284,285,286,287,288,289,291,293,295,298,307,308,314,315,316,319,320,323,353,354,383,384,392,394,395,396,397,398,400,404,409,410,413,420,421,425,426,436,440,444,448,452,456,460,464,468,472,476,480,484,488,492,500,504,508,512,528,540,544,548,552,556,564,576,580,584,588,592,596,600,604,608,612,616,620,624,628,632,636,640,644,648,652,656,660,664,668,672,676,680,684,688,692,696,700,704,708,712,716,720,724,728,732,736,740,744,748,756,760,772,780,784,788,792,796,800,804,808,820,828,832,836,840,844,848,895,896,897,898,899,900,901,902,903,905,906,907,908,909,910,911,912,913,914,916,917,918,919,920,921,922,923,924,925,926,936,937,938,939,940,941,942,943,944,945,946,947,948,949,950,951,952,953,954,957,959,961,963,965,967,969,971,973,975,977,979,981,983,985,987,989,991,9
# ...

# %%
chl = pd.read_csv("../data/background/prgchlp1.csv")  # Chile
chl = chl.loc[:, ['SEQID', 'BIRTHRGN', 'CTRYRGN','FIRLGRGN']]
print(chl["BIRTHRGN"].unique())
# Out:
# ['3' 'N' 3.0 nan 9.0 '9' 2.0]
# ...

# %%
cze = pd.read_csv("../data/background/prgczep1.csv")  # Czechia
cze = cze.loc[:, ['SEQID', 'BIRTHRGN', 'CTRYRGN','FIRLGRGN']]
print(cze["BIRTHRGN"].unique())
# Out:
# ['8' 'N' '5' '9']
# ...

# %%
deu = pd.read_csv("../data/background/prgdeup1.csv")  # Germany
deu = deu.loc[:, ['SEQID', 'BIRTHRGN', 'CTRYRGN','FIRLGRGN']]
print(deu["BIRTHRGN"].unique())
# Out:
# ['N' nan]
# ...

# %%
dnk = pd.read_csv("../data/background/prgdnkp1.csv")  # Denmark
dnk = dnk.loc[:, ['SEQID', 'BIRTHRGN', 'CTRYRGN','FIRLGRGN']]
print(dnk["BIRTHRGN"].unique())
# Out:
# [9.0 8.0 1.0 3.0 4.0 2.0 nan 5.0 6.0 '9' '1' '3' '5' '8' '2' '4' '6' '7'
#  'N' 'D' 7.0]
# ...

# %%
ecu = pd.read_csv("../data/background/prgecup1.csv")  # Ecuador
ecu = ecu.loc[:, ['SEQID', 'BIRTHRGN', 'CTRYRGN','FIRLGRGN']]
print(ecu["BIRTHRGN"].unique())
# Out:
# C:\Users\yukef\AppData\Local\Temp\ipykernel_17756\3715868929.py:1: DtypeWarning: Columns (6,7,9,10,21,22,23,75,104,106,107,108,117,118,241,252,253,254,255,256,257,258,259,260,261,262,263,264,265,266,267,268,269,270,271,272,282,283,284,285,286,287,288,289,290,291,292,293,294,295,296,297,300,309,310,316,317,318,321,322,380,389,391,393,394,396,397,398,399,400,402,406,410,411,412,415,428,432,433,434,437,439,440,441,442,443,461,485,489,493,497,501,505,509,513,517,521,525,533,545,557,561,565,569,577,581,585,589,597,629,633,645,649,653,657,661,665,669,673,677,681,689,697,705,709,713,717,721,725,729,733,737,741,753,757,765,777,781,785,789,793,797,801,805,809,813,817,821,825,829,833,841,845,853,857,877,885,889,893,897,943,945,947,954,955,956,965,966,1006,1008,1010,1012,1014,1016,1018,1020,1022,1024,1026,1028,1030,1032,1034,1036,1038,1040,1042,1044,1046,1048,1050,1052,1054,1056,1058,1060,1062,1064,1066,1068,1070,1072) have mixed types. Specify dtype option on import or set low_memory=False.
# ...

# %%
esp = pd.read_csv("../data/background/prgespp1.csv")  # Spain
esp = esp.loc[:, ['SEQID', 'BIRTHRGN', 'CTRYRGN','FIRLGRGN']]
print(esp["BIRTHRGN"].unique())
# Out:
# ['9' nan '3' '8' 'N' '1' '4' '5' '7' 9.0 3.0 8.0 2.0 5.0 1.0 7.0 4.0 '6'
#  '2' 6.0]
# ...

# %%
est = pd.read_csv("../data/background/prgestp1.csv")  # Estonia
est = est.loc[:, ['SEQID', 'BIRTHRGN', 'CTRYRGN','FIRLGRGN']]
print(est["BIRTHRGN"].unique())
# Out:
# C:\Users\yukef\AppData\Local\Temp\ipykernel_17756\336514307.py:1: DtypeWarning: Columns (6,7,10,14,15,16,75,107,108,118,240,251,252,253,254,255,256,257,258,259,260,261,262,263,264,265,266,267,268,269,270,271,281,282,283,284,285,286,287,288,289,290,291,292,293,294,295,296,299,308,309,315,316,317,324,379,384,385,388,389,390,392,393,395,396,397,398,399,405,410,411,414,421,422,426,427,433,435,437,441,445,449,453,457,461,465,469,473,477,481,485,489,493,497,501,509,513,517,521,525,529,537,541,545,561,565,569,573,577,581,585,589,593,597,601,605,609,613,617,633,637,645,657,661,665,669,673,677,685,689,693,697,701,705,709,713,717,721,725,729,733,737,741,745,749,753,757,761,765,769,773,781,785,789,793,797,801,805,809,821,825,829,833,837,841,845,849,896,898,899,900,901,907,909,910,911,912,913,914,915,917,918,919,920,921,922,923,924,925,940,941,942,943,944,945,946,947,948,949,950,951,952,953,954,955,958,960,962,964,966,968,970,972,974,976,978,980,982,984,986,988,990,992,994,996,998,1000,1002,1004
# ...

# %%
fin = pd.read_csv("../data/background/prgfinp1.csv")  # Finland
fin = fin.loc[:, ['SEQID', 'BIRTHRGN', 'CTRYRGN','FIRLGRGN']]
print(fin["BIRTHRGN"].unique())
# Out:
# ['9' 'N' '8']
# C:\Users\yukef\AppData\Local\Temp\ipykernel_17756\407097661.py:1: DtypeWarning: Columns (7,14,15,16,17,21,107,108,117,118,240,251,252,253,254,255,256,257,258,259,260,261,262,263,264,265,266,267,268,269,271,282,286,287,289,291,292,294,295,296,299,308,309,315,316,317,320,321,324,401,405,421,422,427,437,441,445,449,453,457,461,465,469,473,477,485,489,493,497,501,505,509,513,517,525,529,533,537,541,545,557,561,565,573,577,581,585,589,593,597,601,605,609,613,633,637,641,645,653,661,665,669,673,677,681,685,689,693,697,701,705,709,713,717,721,725,729,733,737,741,745,749,753,757,761,765,769,773,777,781,785,789,793,797,801,805,809,813,821,825,829,833,837,841,845,849,896,897,898,899,900,901,902,903,904,906,907,908,909,910,911,912,913,914,915,916,917,918,919,920,921,922,923,924,925,926,927,937,938,939,940,941,942,943,944,945,946,947,948,949,950,951,952,953,954,955,956,1286,1318) have mixed types. Specify dtype option on import or set low_memory=False.
# ...

# %%
aut = pd.read_csv("../data/background/prgautp1.csv")  # Austria
aut = aut.loc[:, ['SEQID', 'BIRTHRGN', 'CTRYRGN','FIRLGRGN']]
print(aut["BIRTHRGN"].unique())
# Out:
# [8.0 9.0 nan 1.0 2.0 3.0 5.0 4.0 6.0 7.0 '9' '8' '1' 'N' '2' '6']
# ...

# %%
fra = pd.read_csv("../data/background/prgfrap1.csv")  # France
fra = fra.loc[:, ['SEQID', 'BIRTHRGN', 'CTRYRGN','FIRLGRGN']]
print(fra["BIRTHRGN"].unique())
# Out:
# ['9' '1' nan '4' 'N' '8' '2' '5' '3' '6' 1.0 9.0 5.0 8.0 4.0 2.0 '7']
# C:\Users\yukef\AppData\Local\Temp\ipykernel_17756\3216218666.py:1: DtypeWarning: Columns (8,21,22,23,75,104,106,107,108,117,118,240,251,252,253,254,255,256,257,258,259,260,262,263,264,265,266,267,268,269,270,271,287,291,292,299,308,309,315,379,380,388,389,390,392,393,395,396,397,398,399,409,410,411,414,421,422,426,427,437,441,445,449,453,457,461,469,473,477,501,509,513,529,533,541,577,581,585,589,597,605,609,613,637,641,645,653,657,661,665,669,673,677,689,693,697,705,709,713,721,725,729,733,737,741,745,749,753,757,761,765,769,773,781,785,793,797,805,821,829,833,837,849,909,910,911,912,913,914,917,937,938,939,940,941,942,943,944,945,946,947,948,949,950,951,952,953,1286) have mixed types. Specify dtype option on import or set low_memory=False.
#   fra = pd.read_csv("../data/background/prgfrap1.csv")  # France

# %%
gbr = pd.read_csv("../data/background/prggbrp1.csv")  # United Kingdom of Great Britain and Northern Ireland
gbr = gbr.loc[:, ['SEQID', 'BIRTHRGN', 'CTRYRGN','FIRLGRGN']]
print(gbr["BIRTHRGN"].unique())
# Out:
# /var/folders/hv/08dyyt957zq3n_n6kttfl_180000gn/T/ipykernel_19481/2024841478.py:1: DtypeWarning: Columns (75,107,108,118,251,252,253,254,255,256,257,258,259,260,261,263,265,266,267,268,270,271,282,283,284,285,286,287,288,289,290,291,292,293,294,295,296,299,308,309,315,316,317,320,321,324,380,389,390,392,393,395,396,397,398,399,401,409,410,411,414,421,422,427,437,441,445,449,453,457,461,465,469,473,477,481,485,489,493,497,501,505,509,513,517,529,537,541,545,549,553,557,565,577,581,585,589,597,601,605,609,613,617,625,629,633,637,645,653,657,661,665,669,673,677,689,693,697,701,705,709,713,717,721,725,729,733,737,741,745,749,753,757,761,765,769,773,777,781,785,789,793,797,801,805,821,829,833,837,841,845,849,897,899,900,901,902,903,904,907,908,909,910,911,912,913,914,915,917,918,919,920,921,922,923,924,925,926,927,937,938,939,940,941,942,943,944,945,946,947,948,949,950,951,952,953,954,955,956,958,960,962,964,966,968,970,972,974,976,978,980,982,984,986,988,990,992,994,996,998,1000,1002,1004
# ...

# %%
grc = pd.read_csv("../data/background/prggrcp1.csv")  # Greece
grc = grc.loc[:, ['SEQID', 'BIRTHRGN', 'CTRYRGN','FIRLGRGN']]
print(grc["BIRTHRGN"].unique())
# Out:
# [9.0 8.0 6.0 nan 2 1 7 3 4 '9' '8' '6' '5' 'N' '7' '1' '4' 5.0]
# ...

# %%
hun = pd.read_csv("../data/background/prghunp1.csv")  # Hungary
hun = hun.loc[:, ['SEQID', 'BIRTHRGN', 'CTRYRGN','FIRLGRGN']]
print(hun["BIRTHRGN"].unique())
# Out:
# [8.0 nan 9.0 2.0 '8' '2' '9' 'N' 3.0 6.0]
# ...

# %%
irl = pd.read_csv("../data/background/prgirlp1.csv")  # Irland
irl = irl.loc[:, ['SEQID', 'BIRTHRGN', 'CTRYRGN','FIRLGRGN']]
print(irl["BIRTHRGN"].unique())
# Out:
# [2 9 8 4 5 3 1 7 6 nan '9' '4' '8' '2' '5' '7' '3' '1' 'N']
# ...

# %%
isr = pd.read_csv("../data/background/prgisrp1.csv")  # Israel
isr = isr.loc[:, ['SEQID', 'BIRTHRGN', 'CTRYRGN','FIRLGRGN']]
print(isr["BIRTHRGN"].unique())
# Out:
# ['9' '4' nan '1' '3' 'N' '8' '7' '6' '2' 'R' '5']
# C:\Users\yukef\AppData\Local\Temp\ipykernel_17756\2769167601.py:1: DtypeWarning: Columns (9,10,75,104,106,107,108,117,118,241,252,253,254,255,256,257,258,259,261,262,263,264,265,266,267,268,269,270,271,272,380,381,385,386,389,410,411,412,427,428,432,433,485,489,493,497,501,505,509,513,517,521,557,589,593,601,633,645,657,681,685,693,701,705,709,713,721,737,741,753,757,769,777,781,785,789,793,797,801,805,809,821,825,829,833,837,845,853,881,943,944,946,948,949,950,955,957,958,959,960,961,962,985,986,987,988,989,990,991,992,993,994,995,996,997,998,999,1000,1001,1002,1003,1006,1008,1010,1012,1014,1016,1018,1020,1022,1024,1026,1028,1030,1032,1034,1036,1038,1040,1042,1044,1046,1048,1050,1052,1054,1056,1058,1060,1062,1064,1066,1068,1070,1072,1074,1076,1078,1080,1082,1084,1086,1088,1090,1092,1094,1096,1098,1100) have mixed types. Specify dtype option on import or set low_memory=False.
# ...

# %%
import matplotlib.pyplot as plt

# %%
usa = pd.read_csv("../data/background/prgUSAms_s2.csv")
usa
# Out:
# /var/folders/hv/08dyyt957zq3n_n6kttfl_180000gn/T/ipykernel_19481/3306386058.py:1: DtypeWarning: Columns (448,449,450,451,452) have mixed types. Specify dtype option on import or set low_memory=False.
#   usa = pd.read_csv("../data/background/prgUSAms_s2.csv")
#       CNTRYID  CNTRYID_E  CASEID  PERSID SEQID ID_MAJDES  ID_PSU  ID_SSU  \
# 0         840        840  370776  100021                     203       7
# 1         840        840  638739  100243                     215       4
# 2         840        840  753975  100281  2691               515       4
# 3         840        840  350730  100298  3833               305       8
# 4         840        840  576475  100380  4355               501      15
# ...       ...        ...     ...     ...   ...       ...     ...     ...
# 6095      840        840  662604  999649                     206      10
# 6096      840        840  327725  999656  4006               910      18
# ...

# %%
usa = usa.loc[:, ['SEQID', 'BIRTHRGN']]
usa
# Out:
#      SEQID BIRTHRGN
# 0
# 1
# 2     2691        9
# 3     3833        9
# 4     4355        9
# ...    ...      ...
# 6095
# 6096  4006        9
# 6097  3561        9
# 6098
# 6099  4823        9
#
# [6100 rows x 2 columns]

# %%
usa['BIRTHRGN'].unique()
# Out:
# array([' ', '9', '2', '3', '4', '7', '6', '5', '99', '8', '1', '98'],
#       dtype=object)

# %%
val_ex = [' ', '99', '98']
usa = usa.dropna()
usa = usa[~usa['BIRTHRGN'].isin(val_ex)]
usa['BIRTHRGN'].unique()
# Out:
# array(['9', '2', '3', '4', '7', '6', '5', '8', '1'], dtype=object)

# %%
map_rgn = {'1': 'Arab States','2': 'South and West Asia', '3': 'Latin America and the Caribbean','4':'Sub-Saharan Africa','5':'East Asia and the Pacific (poorer countries)','6':'Central Asia','7':'East Asia and the Pacific (richer countries)',7.0:'East Asia and the Pacific (richer countries)','8':'Central and Eastern Europe','9':'North America and Western Europe'}

# Use the map method to replace values in Column2
usa['BIRTHRGN'] = usa['BIRTHRGN'].map(map_rgn)

usa['BIRTHRGN'].unique()
# Out:
# array(['North America and Western Europe', 'South and West Asia',
#        'Latin America and the Caribbean', 'Sub-Saharan Africa',
#        'East Asia and the Pacific (richer countries)', 'Central Asia',
#        'East Asia and the Pacific (poorer countries)',
#        'Central and Eastern Europe', 'Arab States'], dtype=object)

# %%
ps = pd.read_csv('../data/action/ps.csv')

# %%
pscol = ps.columns.str.split("\t")
print(pscol)
# Out:
# Index([['CNTRYID', 'SEQID', 'PS1_u01a_num_of_created_emails', 'PS1_u01a_num_of_diff_emails_views', 'PS1_u01a_num_of_email_views', 'PS1_u01a_num_of_revisited_emails', 'PS1_u01a_seq_of_viewed_emails', 'PS1_u01a_num_help', 'PS1_u01a_first_interaction_time', 'PS1_u01a_time_on_task', 'PS1_u01a_num_cancel', 'PS1_u01b_num_of_created_emails', 'PS1_u01b_num_of_diff_emails_views', 'PS1_u01b_num_of_email_views', 'PS1_u01b_num_of_revisited_emails', 'PS1_u01b_seq_of_viewed_emails', 'PS1_u01b_num_help', 'PS1_u01b_first_interaction_time', 'PS1_u01b_time_on_task', 'PS1_u01b_num_cancel', 'PS1_u03a_num_help', 'PS1_u03a_first_interaction_time', 'PS1_u03a_time_on_task', 'PS1_u03a_num_switching_environment', 'PS1_u03a_num_cancel', 'PS1_u03a_seq_switching_environment', 'PS1_u06a_num_help', 'PS1_u06a_first_interaction_time', 'PS1_u06a_time_on_task', 'PS1_u06a_num_of_diff_visited_pages', 'PS1_u06a_num_of_page_revisits', 'PS1_u06a_num_of_page_visits', 'PS1_u06a_seq_visited_web_pages', 'PS1_u06a_seq_time_spen
# ...

# %%
pscol = list(pscol)
print(pscol)
# Out:
# [['CNTRYID', 'SEQID', 'PS1_u01a_num_of_created_emails', 'PS1_u01a_num_of_diff_emails_views', 'PS1_u01a_num_of_email_views', 'PS1_u01a_num_of_revisited_emails', 'PS1_u01a_seq_of_viewed_emails', 'PS1_u01a_num_help', 'PS1_u01a_first_interaction_time', 'PS1_u01a_time_on_task', 'PS1_u01a_num_cancel', 'PS1_u01b_num_of_created_emails', 'PS1_u01b_num_of_diff_emails_views', 'PS1_u01b_num_of_email_views', 'PS1_u01b_num_of_revisited_emails', 'PS1_u01b_seq_of_viewed_emails', 'PS1_u01b_num_help', 'PS1_u01b_first_interaction_time', 'PS1_u01b_time_on_task', 'PS1_u01b_num_cancel', 'PS1_u03a_num_help', 'PS1_u03a_first_interaction_time', 'PS1_u03a_time_on_task', 'PS1_u03a_num_switching_environment', 'PS1_u03a_num_cancel', 'PS1_u03a_seq_switching_environment', 'PS1_u06a_num_help', 'PS1_u06a_first_interaction_time', 'PS1_u06a_time_on_task', 'PS1_u06a_num_of_diff_visited_pages', 'PS1_u06a_num_of_page_revisits', 'PS1_u06a_num_of_page_visits', 'PS1_u06a_seq_visited_web_pages', 'PS1_u06a_seq_time_spent_on_w
# ...

# %%
ps[pscol[0]] = ps['CNTRYID\tSEQID\tPS1_u01a_num_of_created_emails\tPS1_u01a_num_of_diff_emails_views\tPS1_u01a_num_of_email_views\tPS1_u01a_num_of_revisited_emails\tPS1_u01a_seq_of_viewed_emails\tPS1_u01a_num_help\tPS1_u01a_first_interaction_time\tPS1_u01a_time_on_task\tPS1_u01a_num_cancel\tPS1_u01b_num_of_created_emails\tPS1_u01b_num_of_diff_emails_views\tPS1_u01b_num_of_email_views\tPS1_u01b_num_of_revisited_emails\tPS1_u01b_seq_of_viewed_emails\tPS1_u01b_num_help\tPS1_u01b_first_interaction_time\tPS1_u01b_time_on_task\tPS1_u01b_num_cancel\tPS1_u03a_num_help\tPS1_u03a_first_interaction_time\tPS1_u03a_time_on_task\tPS1_u03a_num_switching_environment\tPS1_u03a_num_cancel\tPS1_u03a_seq_switching_environment\tPS1_u06a_num_help\tPS1_u06a_first_interaction_time\tPS1_u06a_time_on_task\tPS1_u06a_num_of_diff_visited_pages\tPS1_u06a_num_of_page_revisits\tPS1_u06a_num_of_page_visits\tPS1_u06a_seq_visited_web_pages\tPS1_u06a_seq_time_spent_on_web_pages\tPS1_u06a_num_cancel\tPS1_u06b_num_help\tPS1_u06b_first_interaction_time\tPS1_u06b_time_on_task\tPS1_u06b_num_of_diff_visited_pages\tPS1_u06b_num_of_page_revisits\tPS1_u06b_num_of_page_visits\tPS1_u06b_seq_visited_web_pages\tPS1_u06b_seq_time_spent_on_web_pages\tPS1_u06b_num_cancel\tPS1_u21_num_help\tPS1_u21_first_interaction_time\tPS1_u21_time_on_task\tPS1_u21_num_cancel\tPS1_u04a_num_help\tPS1_u04a_first_interaction_time\tPS1_u04a_time_on_task\tPS1_u04a_num_switching_environment\tPS1_u04a_num_cancel\tPS1_u04a_seq_switching_environment\tPS2_u19a_num_help\tPS2_u19a_first_interaction_time\tPS2_u19a_time_on_task\tPS2_u19a_num_switching_environment\tPS2_u19a_num_cancel\tPS2_u19a_seq_switching_environment\tPS2_u19b_num_help\tPS2_u19b_first_interaction_time\tPS2_u19b_time_on_task\tPS2_u19b_num_switching_environment\tPS2_u19b_num_cancel\tPS2_u19b_seq_switching_environment\tPS2_u07_num_help\tPS2_u07_first_interaction_time\tPS2_u07_time_on_task\tPS2_u07_num_of_diff_visited_pages\tPS2_u07_num_of_page_revisits\tPS2_u07_num_of_page_visits\tPS2_u07_seq_visited_web_pages\tPS2_u07_seq_time_spent_on_web_pages\tPS2_u07_num_cancel\tPS2_u02_num_of_created_emails\tPS2_u02_num_of_diff_emails_views\tPS2_u02_num_of_email_views\tPS2_u02_num_of_revisited_emails\tPS2_u02_seq_of_viewed_emails\tPS2_u02_num_help\tPS2_u02_first_interaction_time\tPS2_u02_time_on_task\tPS2_u02_num_of_diff_visited_pages\tPS2_u02_num_of_page_revisits\tPS2_u02_num_of_page_visits\tPS2_u02_seq_visited_web_pages\tPS2_u02_seq_time_spent_on_web_pages\tPS2_u02_num_switching_environment\tPS2_u02_num_cancel\tPS2_u02_seq_switching_environment\tPS2_u16_num_of_created_emails\tPS2_u16_num_of_diff_emails_views\tPS2_u16_num_of_email_views\tPS2_u16_num_of_revisited_emails\tPS2_u16_seq_of_viewed_emails\tPS2_u16_num_help\tPS2_u16_first_interaction_time\tPS2_u16_time_on_task\tPS2_u16_num_cancel\tPS2_u11b_num_of_created_emails\tPS2_u11b_num_of_diff_emails_views\tPS2_u11b_num_of_email_views\tPS2_u11b_num_of_revisited_emails\tPS2_u11b_seq_of_viewed_emails\tPS2_u11b_num_help\tPS2_u11b_first_interaction_time\tPS2_u11b_time_on_task\tPS2_u11b_num_cancel\tPS2_u23_num_of_created_emails\tPS2_u23_num_of_diff_emails_views\tPS2_u23_num_of_email_views\tPS2_u23_num_of_revisited_emails\tPS2_u23_seq_of_viewed_emails\tPS2_u23_num_help\tPS2_u23_first_interaction_time\tPS2_u23_time_on_task\tPS2_u23_num_of_diff_visited_pages\tPS2_u23_num_of_page_revisits\tPS2_u23_num_of_page_visits\tPS2_u23_seq_visited_web_pages\tPS2_u23_seq_time_spent_on_web_pages\tPS2_u23_num_switching_environment\tPS2_u23_num_cancel\tPS2_u23_seq_switching_environment'].apply(lambda x: pd.Series(str(x).split("\t")))
# Out:
# /var/folders/hv/08dyyt957zq3n_n6kttfl_180000gn/T/ipykernel_19481/1238816996.py:1: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
# ...

# %%
ps.drop(columns=ps.columns[0], axis=1, inplace=True)
ps
# Out:
#              CNTRYID SEQID PS1_u01a_num_of_created_emails  \
# 0     ZA6712_US.data     1                             NA
# 1     ZA6712_US.data    10                              0
# 2     ZA6712_US.data  1000                              0
# 3     ZA6712_US.data  1002                             NA
# 4     ZA6712_US.data  1003                             NA
# ...              ...   ...                            ...
# 4089  ZA6712_US.data   995                              0
# 4090  ZA6712_US.data   996                             NA
# 4091  ZA6712_US.data   997                             NA
# 4092  ZA6712_US.data   998                             NA
# 4093  ZA6712_US.data   999                             NA
#
#      PS1_u01a_num_of_diff_emails_views PS1_u01a_num_of_email_views  \
# 0                                   NA                          NA
# 1                                    3                           7
# ...

# %%
usa.dtypes
# Out:
# SEQID       object
# BIRTHRGN    object
# dtype: object

# %%
ps.dtypes
# Out:
# CNTRYID                                object
# SEQID                                  object
# PS1_u01a_num_of_created_emails         object
# PS1_u01a_num_of_diff_emails_views      object
# PS1_u01a_num_of_email_views            object
#                                         ...
# PS2_u23_seq_visited_web_pages          object
# PS2_u23_seq_time_spent_on_web_pages    object
# PS2_u23_num_switching_environment      object
# PS2_u23_num_cancel                     object
# PS2_u23_seq_switching_environment      object
# Length: 125, dtype: object

# %%
df = usa.merge(ps, how='left', on='SEQID')
df
# Out:
#      SEQID                          BIRTHRGN         CNTRYID  \
# 0     2691  North America and Western Europe  ZA6712_US.data
# 1     3833  North America and Western Europe  ZA6712_US.data
# 2     4355  North America and Western Europe  ZA6712_US.data
# 3      258  North America and Western Europe  ZA6712_US.data
# 4     1486  North America and Western Europe  ZA6712_US.data
# ...    ...                               ...             ...
# 4888   706  North America and Western Europe  ZA6712_US.data
# 4889  1681  North America and Western Europe  ZA6712_US.data
# 4890  4006  North America and Western Europe  ZA6712_US.data
# 4891  3561  North America and Western Europe  ZA6712_US.data
# 4892  4823  North America and Western Europe  ZA6712_US.data
#
#      PS1_u01a_num_of_created_emails PS1_u01a_num_of_diff_emails_views  \
# 0                                 0                                 6
# 1                                NA                                NA
# ...

# %%
df['BIRTHRGN'].unique()
# Out:
# array(['North America and Western Europe', 'South and West Asia',
#        'Latin America and the Caribbean', 'Sub-Saharan Africa',
#        'East Asia and the Pacific (richer countries)', 'Central Asia',
#        'East Asia and the Pacific (poorer countries)',
#        'Central and Eastern Europe', 'Arab States'], dtype=object)

# %%
df.replace('NA', np.nan, inplace=True)

# %%
ps12 = df.dropna(subset=df.columns)
ps12
# Out:
#      SEQID                          BIRTHRGN         CNTRYID  \
# 0     2691  North America and Western Europe  ZA6712_US.data
# 14    1253  North America and Western Europe  ZA6712_US.data
# 19    3650  North America and Western Europe  ZA6712_US.data
# 33     147  North America and Western Europe  ZA6712_US.data
# 37    2822  North America and Western Europe  ZA6712_US.data
# ...    ...                               ...             ...
# 4846  1877  North America and Western Europe  ZA6712_US.data
# 4849  4652  North America and Western Europe  ZA6712_US.data
# 4854  2383  North America and Western Europe  ZA6712_US.data
# 4858  4072  North America and Western Europe  ZA6712_US.data
# 4886  1555  North America and Western Europe  ZA6712_US.data
#
#      PS1_u01a_num_of_created_emails PS1_u01a_num_of_diff_emails_views  \
# 0                                 0                                 6
# 14                                0                                 1
# ...

# %%
ps12['BIRTHRGN'].unique()
# Out:
# array(['North America and Western Europe', 'South and West Asia',
#        'Central Asia', 'Latin America and the Caribbean',
#        'East Asia and the Pacific (poorer countries)',
#        'Central and Eastern Europe', 'Sub-Saharan Africa',
#        'East Asia and the Pacific (richer countries)'], dtype=object)

# %%
ps1 = df[df.filter(like='PS1').notna().all(axis=1) & df.filter(like='PS2').isna().all(axis=1)]
ps1
# Out:
#      SEQID                                      BIRTHRGN         CNTRYID  \
# 9     4061              North America and Western Europe  ZA6712_US.data
# 13     473               Latin America and the Caribbean  ZA6712_US.data
# 20    2616              North America and Western Europe  ZA6712_US.data
# 29    4137              North America and Western Europe  ZA6712_US.data
# 36    3541              North America and Western Europe  ZA6712_US.data
# ...    ...                                           ...             ...
# 4872  3905  East Asia and the Pacific (poorer countries)  ZA6712_US.data
# 4875  4775  East Asia and the Pacific (poorer countries)  ZA6712_US.data
# 4881  1246              North America and Western Europe  ZA6712_US.data
# 4882   327              North America and Western Europe  ZA6712_US.data
# 4885    62              North America and Western Europe  ZA6712_US.data
#
#      PS1_u01a_num_of_created_emails PS1_u01a_num_of_diff_emails_views  \
# ...

# %%
ps1['BIRTHRGN'].unique()
# Out:
# array(['North America and Western Europe',
#        'Latin America and the Caribbean', 'South and West Asia',
#        'East Asia and the Pacific (poorer countries)',
#        'East Asia and the Pacific (richer countries)',
#        'Sub-Saharan Africa', 'Central and Eastern Europe', 'Central Asia',
#        'Arab States'], dtype=object)

# %%
ps2 = df[df.filter(like='PS2').notna().all(axis=1) & df.filter(like='PS1').isna().all(axis=1)]
ps2
# Out:
#      SEQID                                      BIRTHRGN         CNTRYID  \
# 11    3637              North America and Western Europe  ZA6712_US.data
# 16    3045              North America and Western Europe  ZA6712_US.data
# 17    3667              North America and Western Europe  ZA6712_US.data
# 31    4306              North America and Western Europe  ZA6712_US.data
# 40    4141              North America and Western Europe  ZA6712_US.data
# ...    ...                                           ...             ...
# 4861   349              North America and Western Europe  ZA6712_US.data
# 4870  3033              North America and Western Europe  ZA6712_US.data
# 4887  1163  East Asia and the Pacific (poorer countries)  ZA6712_US.data
# 4889  1681              North America and Western Europe  ZA6712_US.data
# 4890  4006              North America and Western Europe  ZA6712_US.data
#
#      PS1_u01a_num_of_created_emails PS1_u01a_num_of_diff_emails_views  \
# ...

# %%
ps2['BIRTHRGN'].unique()
# Out:
# array(['North America and Western Europe',
#        'Latin America and the Caribbean', 'South and West Asia',
#        'East Asia and the Pacific (poorer countries)',
#        'East Asia and the Pacific (richer countries)',
#        'Sub-Saharan Africa', 'Central and Eastern Europe', 'Arab States'],
#       dtype=object)

# %% [markdown]
# The count of people from each region doing both PS1 and PS2

# %%
ps12_cnt = ps12['BIRTHRGN'].value_counts()
ps12_rgn = pd.DataFrame({'Value': ps12_cnt.index, 'Count': ps12_cnt.values})

ps12_cnt
# Out:
# North America and Western Europe                610
# Latin America and the Caribbean                  19
# East Asia and the Pacific (poorer countries)     16
# South and West Asia                               8
# Sub-Saharan Africa                                6
# Central Asia                                      1
# Central and Eastern Europe                        1
# East Asia and the Pacific (richer countries)      1
# Name: BIRTHRGN, dtype: int64

# %%
ps1_cnt = ps1['BIRTHRGN'].value_counts()
ps1_rgn = pd.DataFrame({'Value': ps1_cnt.index, 'Count': ps1_cnt.values})

ps1_cnt
# Out:
# North America and Western Europe                621
# Latin America and the Caribbean                  30
# East Asia and the Pacific (poorer countries)     10
# South and West Asia                               6
# Sub-Saharan Africa                                4
# East Asia and the Pacific (richer countries)      3
# Central and Eastern Europe                        2
# Central Asia                                      1
# Arab States                                       1
# Name: BIRTHRGN, dtype: int64

# %%
ps2_cnt = ps2['BIRTHRGN'].value_counts()
ps2_rgn = pd.DataFrame({'Value': ps2_cnt.index, 'Count': ps2_cnt.values})

ps2_cnt
# Out:
# North America and Western Europe                627
# Latin America and the Caribbean                  26
# South and West Asia                               9
# East Asia and the Pacific (poorer countries)      8
# East Asia and the Pacific (richer countries)      5
# Central and Eastern Europe                        2
# Sub-Saharan Africa                                1
# Arab States                                       1
# Name: BIRTHRGN, dtype: int64
